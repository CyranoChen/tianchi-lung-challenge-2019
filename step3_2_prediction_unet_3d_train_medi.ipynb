# %%
# -*- coding: utf-8 -*-
import sys; print('Python %s on %s' % (sys.version, sys.platform))
import os
import time
import json
import random
from glob import glob, iglob
from tqdm import tqdm
import matplotlib.pyplot as plt

import numpy as np; print('numpy', np.__version__)
import pandas as pd; print('pandas', pd.__version__)
import cv2; print('opencv2', cv2.__version__)
import sklearn; print('sklearn', sklearn.__version__)
import tensorflow as tf; print('tensorflow', tf.__version__)
import tensorflow.keras as keras; print('keras', keras.__version__)

import settings
import helper
# Out:
# Python 3.6.8 (default, Jan 14 2019, 11:02:34)
# [GCC 8.0.1 20180414 (experimental) [trunk revision 259383]] on linux
# numpy 1.16.4
# pandas 0.24.2
# opencv2 4.1.0
# sklearn 0.21.2
# tensorflow 1.14.0
# keras 2.2.4-tf

# %% [markdown]
# # 1. Load Meta File and Annotation

# %%
df_meta_train = pd.read_csv(filepath_or_buffer=settings.PREPROCESS_TRAIN_META_FILE, index_col=['seriesuid'])
df_meta_train.index = df_meta_train.index.astype('str')
df_meta_test = pd.read_csv(filepath_or_buffer=settings.PREPROCESS_TEST_META_FILE, index_col=['seriesuid'])
df_meta_test.index = df_meta_test.index.astype('str')

print('meta_train:', df_meta_train.shape, '\n', 'meta_test:', df_meta_test.shape)
# Out:
# meta_train: (1470, 11)
#  meta_test: (222, 11)

# %%
df_annotation = pd.read_csv(filepath_or_buffer=settings.PREPROCESS_ANNOTATION_FILE, index_col=['seriesuid'])
df_annotation.index = df_annotation.index.astype('str')
df_annotation['label'] = df_annotation['label'].astype('int')
print('annotation:', df_annotation.shape, 'distinct lung:', len(set(df_annotation.index)))
# Out:
# annotation: (12218, 16) distinct lung: 1436

# %%
df_annotation.sample(10)
# Out:
#            width  height  slice     vcoordX     vcoordY  vcoordZ  diameterX  \
# seriesuid
# 697842       350     350    309  104.248047   74.511719    129.0   6.835938
# 688571       350     350    235  254.980469  189.355469    135.0   7.519531
# 631024       274     274    330  211.654297   75.189453     88.0  13.914062
# 690557       350     350    310  111.083984  189.013672    270.0   6.835938
# 402074       370     370    210  109.121058  248.593668    133.0   5.058592
# 645480       350     350    295   58.105469  177.392578    143.0   7.519531
# 688322       350     350    380  100.488281  155.175781     90.0  11.621094
# 388757       309     309    280  147.257812  110.745117    195.0  12.673828
# 655923       361     361    260  257.000977  125.503906    135.0   5.640625
# 528297       391     391    342  237.501953  159.607422    166.0  12.982422
#
#            diameterY  diameterZ     originX     originY     originZ  spacingX  \
# seriesuid
# 697842      7.519531        3.0 -176.050003  -14.800000 -265.350006  0.683594
# 688571     11.621094        5.0 -174.658203 -174.658203 -500.765747  0.683594
# 631024      8.562500       10.0 -129.732422 -276.732422 -252.399994  0.535156
# 690557     10.937500        5.0 -176.110809 -174.658203  332.549194  0.683594
# 402074      7.949216        7.0 -189.199997 -185.000000 -821.789978  0.722656
# 645480      8.203125       10.0 -170.300415 -174.658203 -190.553223  0.683594
# 688322     11.621094        5.0 -181.921158 -174.658203 -556.596436  0.683594
# 388757     14.484375        5.0 -141.198242 -300.198242 -883.500000  0.603516
# 655923      9.166016        5.0 -167.800446 -180.147461 -322.552246  0.705078
# 528297     12.982422        1.0 -202.537994  -77.900002 -364.190002  0.763672
#
#            spacingY  spacingZ  label
# seriesuid
# 697842     0.683594       3.0      1
# 688571     0.683594       5.0      1
# 631024     0.535156       5.0      5
# 690557     0.683594       5.0      1
# 402074     0.722656       7.0      1
# 645480     0.683594       5.0      1
# 688322     0.683594       5.0      5
# 388757     0.603516       5.0     31
# 655923     0.705078       5.0      1
# 528297     0.763672       1.0     31

# %% [markdown]
# # 2. Load Center Coords by Candidates

# %%
lungs = list(set(df_meta_train.index))
random.shuffle(lungs)
print('distinct lungs:', len(lungs))
# Out:
# distinct lungs: 1470

# %%
list_tasks = []
size = settings.CUBE_SIZE
step = 32
start = [ size//2, size//2, size//2 ] # z,y,x
limit = 100

count = 0
for uid in tqdm(lungs):
    meta = df_meta_train.loc[uid] # slice
    
    for z in range(start[0], int(meta.slice), step):
        for y in range(start[1], int(meta.height), step):
            for x in range(start[2], int(meta.width), step):
                task = {}
                task['seriesuid'] = uid
                task['vcoordX'] = x
                task['vcoordY'] = y
                task['vcoordZ'] = z
                
                # print(task)
                list_tasks.append(task)
    
    count += 1
    
    if count >= limit:
        break
# Out:
#   5%|▍         | 69/1470 [00:00<00:04, 345.95it/s]

# %%
# df_tasks = pd.DataFrame(list_tasks, columns=['seriesuid','vcoordX','vcoordY','vcoordZ'])
# df_tasks = df_tasks.set_index('seriesuid')
# df_tasks.index = df_tasks.index.astype('str')

# print('total:', df_tasks.shape, 'lung:', len(set(df_tasks.index)))

# if not os.path.exists(settings.SUBMISSION_DIR + 'train'):
#     os.mkdir(settings.SUBMISSION_DIR + 'train')
    
# df_tasks.to_csv(settings.SUBMISSION_DIR + 'train' + '/tasks_cubes_medi.csv', encoding='utf-8')

# %%
df_tasks = pd.read_csv(filepath_or_buffer=settings.SUBMISSION_DIR + 'train' + '/tasks_cubes_medi.csv', index_col=['seriesuid'])
df_tasks.index = df_tasks.index.astype('str')

print('total:', df_tasks.shape, 'distinct lung:', len(set(df_tasks.index)))
# Out:
# total: (94702, 3) distinct lung: 100

# %% [markdown]
# # 3. Predict Results by tasks_cubes.csv

# %%
# set gpu visible environment variable
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
config = tf.ConfigProto()

# gpu allow_growth
config.gpu_options.allow_growth = True
keras.backend.set_session(tf.Session(config=config))

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred):
    SMOOTH = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + SMOOTH) / (K.sum(y_true_f) + K.sum(y_pred_f) + SMOOTH)

def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

label = '31'
output_dir = './output/unet3d/1564409330/' # labels in center coord
model = load_model(output_dir + "model-best.hd5", 
                   custom_objects={'dice_coef_loss': dice_coef_loss, 'dice_coef': dice_coef})
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0730 14:37:06.151365 140431665747776 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0730 14:37:06.152518 140431665747776 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0730 14:37:06.158895 140431665747776 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:97: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
batch_size = 64
threshold_probability = 0.8
wtype = 'medi'
plot = False

# %%
def plot_cube(cube, rows=8, cols=8):
    num_z, h, w = cube.shape # z,y,x
    assert rows * cols == num_z
    
    img = np.zeros((rows * h, cols * w), dtype=np.uint8)

    for row in range(rows):
        for col in range(cols):
            y = row * h
            x = col * w
            img[y:(y+h), x:(x+w)] = cube[row * cols + col,:,:]
    
    fig, axs = plt.subplots(1, 1, figsize=(32, 32), sharex=True, sharey=True)
    axs.imshow(img, cmap='gray')
    plt.show()

# %%
list_results = []
print(wtype, 'window')
for uid in set(df_tasks.index):
    tasks = df_tasks.loc[[uid]] # DataFrame
    meta = df_meta_train.loc[uid] # slice
    
    print('lung:', uid, 'tasks:', len(tasks), 'meta:', meta.slice, meta.height, meta.width)
#     print(meta)
                 
    lung_l, mask_l = helper.load_lung_array(uid, int(meta.width), int(meta.height), int(meta.slice), 
                                            mode='train', wtype=wtype)

    lung = (lung_l*(mask_l>0)).astype('float') / 255

    count = 0
    for idx, item in tasks.iterrows():
        if count % (batch_size*100) == 0:
            X_item = []
            X_test = []

        # patch without mask
        cube = helper.get_cube_from_lung_array(lung, item.vcoordX, item.vcoordY, item.vcoordZ, 
                                               block_size=settings.CUBE_SIZE)

        if np.sum(cube) > 0:
            X_item.append(item)
            X_test.append(cube)
#         else:
#             print('nothing in coord:', '\n', item)

        if (count % (batch_size*100) == (batch_size*100 - 1) or count == len(tasks) - 1) and len(X_test) > 0:
            assert len(X_item) == len(X_test) or count == len(tasks) - 1

            # Make predictions
            X_test = np.expand_dims(np.asarray(X_test), axis=-1)
            print(X_test.shape)
            predictions_test = model.predict(X_test, batch_size=batch_size, verbose=1)

            for i in range(len(X_item)):
                itm = X_item[i]
                pred = predictions_test[i] > threshold_probability
                pred_cube = predictions_test[i,:,:,:,0]
                pred_mask = pred[:,:,:,0]
            
                if np.sum(pred) > 10:
                    vcoords, diameters, bboxes = helper.get_regions_detail(pred[:,:,:,0], itm)
                    if len(bboxes) > 0:
                        for i, b in enumerate(bboxes):
                            result = {}
                            result['seriesuid'] = uid
                            result['vcoordX'] = vcoords[i][2]
                            result['vcoordY'] = vcoords[i][1]
                            result['vcoordZ'] = vcoords[i][0]
                            result['diametersX'] = diameters[i][2]
                            result['diametersY'] = diameters[i][1]
                            result['diametersZ'] = diameters[i][0]
                            
                            region = pred_cube[b[0]:b[3],b[1]:b[4],b[2]:b[5]]
                            result['probability'] = region[region>threshold_probability].mean()
                            if plot:
                                plot_cube((pred*255).astype(np.uint8))

                            list_results.append(result)
                        
        count += 1
   
    # save the csv by per lung
    df_results = pd.DataFrame(list_results, columns=['seriesuid','vcoordX','vcoordY','vcoordZ','diametersX','diametersY','diametersZ','probability'])
    df_results = df_results.set_index('seriesuid')
    df_results.index = df_results.index.astype('str')

    print('total:', df_results.shape, 'lung:', len(set(df_results.index)))

    df_results.to_csv(settings.SUBMISSION_DIR + 'train' + '/tasks_' + wtype + '_' + label + '.csv', encoding='utf-8')

    print('-'*100)
# Out:
# medi window
# lung: 655457 tasks: 567 meta: 230.0 306.0 306.0
# (567, 64, 64, 64, 1)
# 567/567 [==============================] - 18s 32ms/sample
# total: (83, 7) lung: 1
# ----------------------------------------------------------------------------------------------------
# lung: 672912 tasks: 1296 meta: 300.0 401.0 401.0
# (1199, 64, 64, 64, 1)
# 1199/1199 [==============================] - 24s 20ms/sample
# total: (243, 7) lung: 2
# ----------------------------------------------------------------------------------------------------
# lung: 400058 tasks: 729 meta: 320.0 291.0 291.0
# (692, 64, 64, 64, 1)
# 692/692 [==============================] - 15s 22ms/sample
# total: (433, 7) lung: 3
# ----------------------------------------------------------------------------------------------------
# lung: 671752 tasks: 729 meta: 320.0 306.0 306.0
# (719, 64, 64, 64, 1)
# 719/719 [==============================] - 14s 20ms/sample
# total: (549, 7) lung: 4
# ----------------------------------------------------------------------------------------------------
# lung: 656238 tasks: 1089 meta: 294.0 383.0 383.0
# (987, 64, 64, 64, 1)
# 987/987 [==============================] - 20s 20ms/sample
# total: (661, 7) lung: 5
# ----------------------------------------------------------------------------------------------------
# lung: 689860 tasks: 648 meta: 280.0 319.0 319.0
# (626, 64, 64, 64, 1)
# 626/626 [==============================] - 14s 22ms/sample
# total: (737, 7) lung: 6
# ----------------------------------------------------------------------------------------------------
# lung: 656778 tasks: 900 meta: 290.0 333.0 333.0
# (726, 64, 64, 64, 1)
# 726/726 [==============================] - 15s 21ms/sample
# total: (797, 7) lung: 7
# ----------------------------------------------------------------------------------------------------
# lung: 656794 tasks: 1089 meta: 315.0 370.0 370.0
# (975, 64, 64, 64, 1)
# 975/975 [==============================] - 19s 20ms/sample
# total: (899, 7) lung: 8
# ----------------------------------------------------------------------------------------------------
# lung: 639534 tasks: 900 meta: 315.0 350.0 350.0
# (821, 64, 64, 64, 1)
# 821/821 [==============================] - 18s 21ms/sample
# total: (1150, 7) lung: 9
# ----------------------------------------------------------------------------------------------------
# lung: 673869 tasks: 1152 meta: 280.0 391.0 391.0
# (1044, 64, 64, 64, 1)
# 1044/1044 [==============================] - 21s 20ms/sample
# total: (1269, 7) lung: 10
# ----------------------------------------------------------------------------------------------------
# lung: 653671 tasks: 700 meta: 252.0 350.0 350.0
# (668, 64, 64, 64, 1)
# 668/668 [==============================] - 14s 21ms/sample
# total: (1357, 7) lung: 11
# ----------------------------------------------------------------------------------------------------
# lung: 682056 tasks: 900 meta: 310.0 350.0 350.0
# (899, 64, 64, 64, 1)
# 899/899 [==============================] - 18s 20ms/sample
# total: (1530, 7) lung: 12
# ----------------------------------------------------------------------------------------------------
# lung: 656074 tasks: 729 meta: 315.0 318.0 318.0
# (695, 64, 64, 64, 1)
# 695/695 [==============================] - 13s 19ms/sample
# total: (1669, 7) lung: 13
# ----------------------------------------------------------------------------------------------------
# lung: 664003 tasks: 700 meta: 256.0 330.0 330.0
# (700, 64, 64, 64, 1)
# 700/700 [==============================] - 16s 22ms/sample
# total: (1791, 7) lung: 14
# ----------------------------------------------------------------------------------------------------
# lung: 529278 tasks: 1331 meta: 355.0 379.0 379.0
# (1167, 64, 64, 64, 1)
# 1167/1167 [==============================] - 23s 20ms/sample
# total: (2031, 7) lung: 15
# ----------------------------------------------------------------------------------------------------
# lung: 672344 tasks: 900 meta: 300.0 350.0 350.0
# (880, 64, 64, 64, 1)
# 880/880 [==============================] - 19s 21ms/sample
# total: (2142, 7) lung: 16
# ----------------------------------------------------------------------------------------------------
# lung: 647210 tasks: 800 meta: 285.0 350.0 350.0
# (754, 64, 64, 64, 1)
# 754/754 [==============================] - 15s 20ms/sample
# total: (2259, 7) lung: 17
# ----------------------------------------------------------------------------------------------------
# lung: 689340 tasks: 968 meta: 285.0 378.0 378.0
# (873, 64, 64, 64, 1)
# 873/873 [==============================] - 19s 21ms/sample
# total: (2390, 7) lung: 18
# ----------------------------------------------------------------------------------------------------
# lung: 655431 tasks: 1296 meta: 312.0 407.0 407.0
# (995, 64, 64, 64, 1)
# 995/995 [==============================] - 20s 20ms/sample
# total: (2501, 7) lung: 19
# ----------------------------------------------------------------------------------------------------
# lung: 664658 tasks: 500 meta: 170.0 350.0 350.0
# (481, 64, 64, 64, 1)
# 481/481 [==============================] - 10s 21ms/sample
# total: (2568, 7) lung: 20
# ----------------------------------------------------------------------------------------------------
# lung: 655992 tasks: 1100 meta: 365.0 350.0 350.0
# (1011, 64, 64, 64, 1)
# 1011/1011 [==============================] - 21s 21ms/sample
# total: (2709, 7) lung: 21
# ----------------------------------------------------------------------------------------------------
# lung: 681379 tasks: 1008 meta: 256.0 385.0 385.0
# (956, 64, 64, 64, 1)
# 956/956 [==============================] - 18s 19ms/sample
# total: (2877, 7) lung: 22
# ----------------------------------------------------------------------------------------------------
# lung: 679994 tasks: 700 meta: 255.0 350.0 350.0
# (660, 64, 64, 64, 1)
# 660/660 [==============================] - 13s 20ms/sample
# total: (3104, 7) lung: 23
# ----------------------------------------------------------------------------------------------------
# lung: 631673 tasks: 567 meta: 250.0 314.0 314.0
# (565, 64, 64, 64, 1)
# 565/565 [==============================] - 11s 20ms/sample
# total: (3208, 7) lung: 24
# ----------------------------------------------------------------------------------------------------
# lung: 671750 tasks: 648 meta: 270.0 320.0 320.0
# (628, 64, 64, 64, 1)
# 628/628 [==============================] - 12s 20ms/sample
# total: (3294, 7) lung: 25
# ----------------------------------------------------------------------------------------------------
# lung: 688185 tasks: 900 meta: 300.0 322.0 322.0
# (808, 64, 64, 64, 1)
# 808/808 [==============================] - 17s 21ms/sample
# total: (3391, 7) lung: 26
# ----------------------------------------------------------------------------------------------------
# lung: 684424 tasks: 968 meta: 275.0 359.0 359.0
# (846, 64, 64, 64, 1)
# 846/846 [==============================] - 17s 21ms/sample
# total: (3504, 7) lung: 27
# ----------------------------------------------------------------------------------------------------
# lung: 688225 tasks: 847 meta: 245.0 357.0 357.0
# (788, 64, 64, 64, 1)
# 788/788 [==============================] - 15s 19ms/sample
# total: (3689, 7) lung: 28
# ----------------------------------------------------------------------------------------------------
# lung: 656881 tasks: 1000 meta: 345.0 350.0 350.0
# (915, 64, 64, 64, 1)
# 915/915 [==============================] - 19s 21ms/sample
# total: (3922, 7) lung: 29
# ----------------------------------------------------------------------------------------------------
# lung: 690660 tasks: 567 meta: 231.0 319.0 319.0
# (498, 64, 64, 64, 1)
# 498/498 [==============================] - 10s 20ms/sample
# total: (3998, 7) lung: 30
# ----------------------------------------------------------------------------------------------------
# lung: 695349 tasks: 648 meta: 285.0 317.0 317.0
# (606, 64, 64, 64, 1)
# 606/606 [==============================] - 13s 21ms/sample
# total: (4078, 7) lung: 31
# ----------------------------------------------------------------------------------------------------
# lung: 647735 tasks: 900 meta: 300.0 350.0 350.0
# (879, 64, 64, 64, 1)
# 879/879 [==============================] - 17s 20ms/sample
# total: (4207, 7) lung: 32
# ----------------------------------------------------------------------------------------------------
# lung: 689252 tasks: 1584 meta: 365.0 392.0 392.0
# (1404, 64, 64, 64, 1)
# 1404/1404 [==============================] - 28s 20ms/sample
# total: (4388, 7) lung: 33
# ----------------------------------------------------------------------------------------------------
# lung: 656403 tasks: 1440 meta: 324.0 394.0 394.0
# (1188, 64, 64, 64, 1)
# 1188/1188 [==============================] - 25s 21ms/sample
# total: (4553, 7) lung: 34
# ----------------------------------------------------------------------------------------------------
# lung: 655574 tasks: 968 meta: 280.0 381.0 381.0
# (906, 64, 64, 64, 1)
# 906/906 [==============================] - 18s 20ms/sample
# total: (4699, 7) lung: 35
# ----------------------------------------------------------------------------------------------------
# lung: 520069 tasks: 1690 meta: 340.0 427.0 427.0
# (1433, 64, 64, 64, 1)
# 1433/1433 [==============================] - 29s 20ms/sample
# total: (4839, 7) lung: 36
# ----------------------------------------------------------------------------------------------------
# lung: 691784 tasks: 900 meta: 300.0 350.0 350.0
# (871, 64, 64, 64, 1)
# 871/871 [==============================] - 18s 21ms/sample
# total: (4941, 7) lung: 37
# ----------------------------------------------------------------------------------------------------
# lung: 689288 tasks: 900 meta: 300.0 350.0 350.0
# (862, 64, 64, 64, 1)
# 862/862 [==============================] - 17s 20ms/sample
# total: (5187, 7) lung: 38
# ----------------------------------------------------------------------------------------------------
# lung: 696427 tasks: 968 meta: 280.0 357.0 357.0
# (951, 64, 64, 64, 1)
# 951/951 [==============================] - 18s 19ms/sample
# total: (5280, 7) lung: 39
# ----------------------------------------------------------------------------------------------------
# lung: 672672 tasks: 640 meta: 340.0 282.0 282.0
# (614, 64, 64, 64, 1)
# 614/614 [==============================] - 13s 22ms/sample
# total: (5432, 7) lung: 40
# ----------------------------------------------------------------------------------------------------
# lung: 655376 tasks: 1690 meta: 330.0 436.0 436.0
# (1284, 64, 64, 64, 1)
# 1284/1284 [==============================] - 25s 20ms/sample
# total: (5597, 7) lung: 41
# ----------------------------------------------------------------------------------------------------
# lung: 388509 tasks: 1152 meta: 285.0 406.0 406.0
# (1032, 64, 64, 64, 1)
# 1032/1032 [==============================] - 21s 20ms/sample
# total: (5741, 7) lung: 42
# ----------------------------------------------------------------------------------------------------
# lung: 648146 tasks: 1000 meta: 340.0 350.0 350.0
# (999, 64, 64, 64, 1)
# 999/999 [==============================] - 19s 19ms/sample
# total: (5867, 7) lung: 43
# ----------------------------------------------------------------------------------------------------
# lung: 648428 tasks: 512 meta: 260.0 288.0 288.0
# (512, 64, 64, 64, 1)
# 512/512 [==============================] - 10s 20ms/sample
# total: (5913, 7) lung: 44
# ----------------------------------------------------------------------------------------------------
# lung: 657280 tasks: 800 meta: 270.0 350.0 350.0
# (702, 64, 64, 64, 1)
# 702/702 [==============================] - 15s 22ms/sample
# total: (6104, 7) lung: 45
# ----------------------------------------------------------------------------------------------------
# lung: 676182 tasks: 648 meta: 260.0 312.0 312.0
# (556, 64, 64, 64, 1)
# 556/556 [==============================] - 12s 22ms/sample
# total: (6204, 7) lung: 46
# ----------------------------------------------------------------------------------------------------
# lung: 689390 tasks: 800 meta: 280.0 350.0 350.0
# (792, 64, 64, 64, 1)
# 792/792 [==============================] - 16s 20ms/sample
# total: (6344, 7) lung: 47
# ----------------------------------------------------------------------------------------------------
# lung: 655698 tasks: 1000 meta: 330.0 350.0 350.0
# (917, 64, 64, 64, 1)
# 917/917 [==============================] - 18s 20ms/sample
# total: (6463, 7) lung: 48
# ----------------------------------------------------------------------------------------------------
# lung: 655426 tasks: 900 meta: 310.0 339.0 339.0
# (832, 64, 64, 64, 1)
# 832/832 [==============================] - 17s 20ms/sample
# total: (6577, 7) lung: 49
# ----------------------------------------------------------------------------------------------------
# lung: 664574 tasks: 1000 meta: 350.0 350.0 350.0
# (901, 64, 64, 64, 1)
# 901/901 [==============================] - 18s 20ms/sample
# total: (6679, 7) lung: 50
# ----------------------------------------------------------------------------------------------------
# lung: 382339 tasks: 847 meta: 238.0 370.0 370.0
# (705, 64, 64, 64, 1)
# 705/705 [==============================] - 14s 21ms/sample
# total: (6794, 7) lung: 51
# ----------------------------------------------------------------------------------------------------
# lung: 682359 tasks: 729 meta: 305.0 291.0 291.0
# (701, 64, 64, 64, 1)
# 701/701 [==============================] - 16s 22ms/sample
# total: (6916, 7) lung: 52
# ----------------------------------------------------------------------------------------------------
# lung: 653891 tasks: 900 meta: 305.0 350.0 350.0
# (898, 64, 64, 64, 1)
# 898/898 [==============================] - 19s 21ms/sample
# total: (7051, 7) lung: 53
# ----------------------------------------------------------------------------------------------------
# lung: 397750 tasks: 1584 meta: 360.0 390.0 390.0
# (1149, 64, 64, 64, 1)
# 1149/1149 [==============================] - 22s 19ms/sample
# total: (7218, 7) lung: 54
# ----------------------------------------------------------------------------------------------------
# lung: 503406 tasks: 1296 meta: 296.0 396.0 396.0
# (1056, 64, 64, 64, 1)
# 1056/1056 [==============================] - 22s 20ms/sample
# total: (7376, 7) lung: 55
# ----------------------------------------------------------------------------------------------------
# lung: 663672 tasks: 700 meta: 250.0 350.0 350.0
# (665, 64, 64, 64, 1)
# 665/665 [==============================] - 14s 21ms/sample
# total: (7473, 7) lung: 56
# ----------------------------------------------------------------------------------------------------
# lung: 543981 tasks: 2700 meta: 400.0 500.0 500.0
# (1729, 64, 64, 64, 1)
# 1729/1729 [==============================] - 34s 20ms/sample
# total: (7712, 7) lung: 57
# ----------------------------------------------------------------------------------------------------
# lung: 637993 tasks: 900 meta: 310.0 350.0 350.0
# (864, 64, 64, 64, 1)
# 864/864 [==============================] - 17s 19ms/sample
# total: (7825, 7) lung: 58
# ----------------------------------------------------------------------------------------------------
# lung: 679809 tasks: 900 meta: 300.0 350.0 350.0
# (886, 64, 64, 64, 1)
# 886/886 [==============================] - 19s 22ms/sample
# total: (7964, 7) lung: 59
# ----------------------------------------------------------------------------------------------------
# lung: 672499 tasks: 810 meta: 330.0 318.0 318.0
# (785, 64, 64, 64, 1)
# 785/785 [==============================] - 16s 21ms/sample
# total: (8110, 7) lung: 60
# ----------------------------------------------------------------------------------------------------
# lung: 655394 tasks: 1296 meta: 301.0 410.0 410.0
# (1132, 64, 64, 64, 1)
# 1132/1132 [==============================] - 22s 19ms/sample
# total: (8230, 7) lung: 61
# ----------------------------------------------------------------------------------------------------
# lung: 697125 tasks: 729 meta: 304.0 317.0 317.0
# (687, 64, 64, 64, 1)
# 687/687 [==============================] - 13s 20ms/sample
# total: (8360, 7) lung: 62
# ----------------------------------------------------------------------------------------------------
# lung: 682499 tasks: 1089 meta: 310.0 354.0 354.0
# (1028, 64, 64, 64, 1)
# 1028/1028 [==============================] - 20s 19ms/sample
# total: (8552, 7) lung: 63
# ----------------------------------------------------------------------------------------------------
# lung: 674849 tasks: 968 meta: 275.0 371.0 371.0
# (869, 64, 64, 64, 1)
# 869/869 [==============================] - 18s 21ms/sample
# total: (8644, 7) lung: 64
# ----------------------------------------------------------------------------------------------------
# lung: 320188 tasks: 968 meta: 280.0 370.0 370.0
# (827, 64, 64, 64, 1)
# 827/827 [==============================] - 18s 22ms/sample
# total: (8818, 7) lung: 65
# ----------------------------------------------------------------------------------------------------
# lung: 645337 tasks: 900 meta: 320.0 350.0 350.0
# (812, 64, 64, 64, 1)
# 812/812 [==============================] - 16s 19ms/sample
# total: (8960, 7) lung: 66
# ----------------------------------------------------------------------------------------------------
# lung: 502378 tasks: 512 meta: 260.0 280.0 280.0
# (481, 64, 64, 64, 1)
# 481/481 [==============================] - 9s 20ms/sample
# total: (9037, 7) lung: 67
# ----------------------------------------------------------------------------------------------------
# lung: 402074 tasks: 726 meta: 210.0 370.0 370.0
# (625, 64, 64, 64, 1)
# 625/625 [==============================] - 14s 23ms/sample
# total: (9146, 7) lung: 68
# ----------------------------------------------------------------------------------------------------
# lung: 696418 tasks: 800 meta: 285.0 350.0 350.0
# (730, 64, 64, 64, 1)
# 730/730 [==============================] - 15s 21ms/sample
# total: (9231, 7) lung: 69
# ----------------------------------------------------------------------------------------------------
# lung: 657065 tasks: 1000 meta: 328.0 330.0 330.0
# (924, 64, 64, 64, 1)
# 924/924 [==============================] - 19s 20ms/sample
# total: (9410, 7) lung: 70
# ----------------------------------------------------------------------------------------------------
# lung: 687474 tasks: 900 meta: 310.0 350.0 350.0
# (859, 64, 64, 64, 1)
# 859/859 [==============================] - 17s 20ms/sample
# total: (9537, 7) lung: 71
# ----------------------------------------------------------------------------------------------------
# lung: 628766 tasks: 900 meta: 300.0 350.0 350.0
# (876, 64, 64, 64, 1)
# 876/876 [==============================] - 17s 19ms/sample
# total: (9701, 7) lung: 72
# ----------------------------------------------------------------------------------------------------
# lung: 698734 tasks: 600 meta: 200.0 326.0 326.0
# (562, 64, 64, 64, 1)
# 562/562 [==============================] - 11s 20ms/sample
# total: (9820, 7) lung: 73
# ----------------------------------------------------------------------------------------------------
# lung: 688374 tasks: 648 meta: 270.0 309.0 309.0
# (605, 64, 64, 64, 1)
# 605/605 [==============================] - 13s 21ms/sample
# total: (9922, 7) lung: 74
# ----------------------------------------------------------------------------------------------------
# lung: 693057 tasks: 1296 meta: 300.0 397.0 397.0
# (1197, 64, 64, 64, 1)
# 1197/1197 [==============================] - 26s 21ms/sample
# total: (10079, 7) lung: 75
# ----------------------------------------------------------------------------------------------------
# lung: 656835 tasks: 1210 meta: 333.0 356.0 356.0
# (997, 64, 64, 64, 1)
# 997/997 [==============================] - 20s 20ms/sample
# total: (10181, 7) lung: 76
# ----------------------------------------------------------------------------------------------------
# lung: 657237 tasks: 1100 meta: 365.0 341.0 341.0
# (962, 64, 64, 64, 1)
# 962/962 [==============================] - 19s 20ms/sample
# total: (10337, 7) lung: 77
# ----------------------------------------------------------------------------------------------------
# lung: 688892 tasks: 1000 meta: 325.0 340.0 340.0
# (955, 64, 64, 64, 1)
# 955/955 [==============================] - 18s 19ms/sample
# total: (10496, 7) lung: 78
# ----------------------------------------------------------------------------------------------------
# lung: 655633 tasks: 810 meta: 325.0 302.0 302.0
# (778, 64, 64, 64, 1)
# 778/778 [==============================] - 15s 20ms/sample
# total: (10595, 7) lung: 79
# ----------------------------------------------------------------------------------------------------
# lung: 689544 tasks: 1100 meta: 365.0 350.0 350.0
# (1008, 64, 64, 64, 1)
# 1008/1008 [==============================] - 19s 19ms/sample
# total: (10778, 7) lung: 80
# ----------------------------------------------------------------------------------------------------
# lung: 688928 tasks: 1089 meta: 295.0 364.0 364.0
# (994, 64, 64, 64, 1)
# 994/994 [==============================] - 21s 21ms/sample
# total: (10911, 7) lung: 81
# ----------------------------------------------------------------------------------------------------
# lung: 671831 tasks: 900 meta: 295.0 352.0 352.0
# (811, 64, 64, 64, 1)
# 811/811 [==============================] - 18s 22ms/sample
# total: (11077, 7) lung: 82
# ----------------------------------------------------------------------------------------------------
# lung: 656465 tasks: 1352 meta: 270.0 441.0 441.0
# (1175, 64, 64, 64, 1)
# 1175/1175 [==============================] - 24s 20ms/sample
# total: (11228, 7) lung: 83
# ----------------------------------------------------------------------------------------------------
# lung: 648061 tasks: 1296 meta: 310.0 390.0 390.0
# (1228, 64, 64, 64, 1)
# 1228/1228 [==============================] - 24s 20ms/sample
# total: (11365, 7) lung: 84
# ----------------------------------------------------------------------------------------------------
# lung: 657795 tasks: 648 meta: 285.0 313.0 313.0
# (584, 64, 64, 64, 1)
# 584/584 [==============================] - 12s 20ms/sample
# total: (11450, 7) lung: 85
# ----------------------------------------------------------------------------------------------------
# lung: 689124 tasks: 1000 meta: 350.0 341.0 341.0
# (969, 64, 64, 64, 1)
# 969/969 [==============================] - 20s 20ms/sample
# total: (11619, 7) lung: 86
# ----------------------------------------------------------------------------------------------------
# lung: 682280 tasks: 1089 meta: 305.0 384.0 384.0
# (1035, 64, 64, 64, 1)
# 1035/1035 [==============================] - 21s 21ms/sample
# total: (11778, 7) lung: 87
# ----------------------------------------------------------------------------------------------------
# lung: 414510 tasks: 1089 meta: 290.0 368.0 368.0
# (955, 64, 64, 64, 1)
# 955/955 [==============================] - 19s 20ms/sample
# total: (11907, 7) lung: 88
# ----------------------------------------------------------------------------------------------------
# lung: 401070 tasks: 486 meta: 215.0 296.0 296.0
# (454, 64, 64, 64, 1)
# 454/454 [==============================] - 10s 21ms/sample
# total: (11995, 7) lung: 89
# ----------------------------------------------------------------------------------------------------
# lung: 632344 tasks: 700 meta: 230.0 350.0 350.0
# (683, 64, 64, 64, 1)
# 683/683 [==============================] - 14s 20ms/sample
# total: (12082, 7) lung: 90
# ----------------------------------------------------------------------------------------------------
# lung: 657853 tasks: 1296 meta: 300.0 392.0 392.0
# (1089, 64, 64, 64, 1)
# 1089/1089 [==============================] - 21s 20ms/sample
# total: (12246, 7) lung: 91
# ----------------------------------------------------------------------------------------------------
# lung: 697073 tasks: 900 meta: 300.0 350.0 350.0
# (856, 64, 64, 64, 1)
# 856/856 [==============================] - 17s 19ms/sample
# total: (12469, 7) lung: 92
# ----------------------------------------------------------------------------------------------------
# lung: 656330 tasks: 1000 meta: 325.0 350.0 350.0
# (874, 64, 64, 64, 1)
# 874/874 [==============================] - 19s 21ms/sample
# total: (12588, 7) lung: 93
# ----------------------------------------------------------------------------------------------------
# lung: 655432 tasks: 847 meta: 252.0 378.0 378.0
# (810, 64, 64, 64, 1)
# 810/810 [==============================] - 16s 20ms/sample
# total: (12685, 7) lung: 94
# ----------------------------------------------------------------------------------------------------
# lung: 390571 tasks: 648 meta: 280.0 303.0 303.0
# (633, 64, 64, 64, 1)
# 633/633 [==============================] - 14s 22ms/sample
# total: (12765, 7) lung: 95
# ----------------------------------------------------------------------------------------------------
# lung: 688190 tasks: 800 meta: 270.0 350.0 350.0
# (749, 64, 64, 64, 1)
# 749/749 [==============================] - 14s 19ms/sample
# total: (12884, 7) lung: 96
# ----------------------------------------------------------------------------------------------------
# lung: 689419 tasks: 1000 meta: 321.0 350.0 350.0
# (967, 64, 64, 64, 1)
# 967/967 [==============================] - 19s 20ms/sample
# total: (12964, 7) lung: 97
# ----------------------------------------------------------------------------------------------------
# lung: 639006 tasks: 576 meta: 300.0 280.0 280.0
# (571, 64, 64, 64, 1)
# 571/571 [==============================] - 11s 19ms/sample
# total: (13042, 7) lung: 98
# ----------------------------------------------------------------------------------------------------
# lung: 630889 tasks: 800 meta: 270.0 346.0 346.0
# (792, 64, 64, 64, 1)
# 792/792 [==============================] - 15s 20ms/sample
# total: (13157, 7) lung: 99
# ----------------------------------------------------------------------------------------------------
# lung: 663638 tasks: 900 meta: 315.0 350.0 350.0
# (876, 64, 64, 64, 1)
# 876/876 [==============================] - 17s 19ms/sample
# total: (13277, 7) lung: 100
# ----------------------------------------------------------------------------------------------------

# %%
df_results = pd.read_csv(filepath_or_buffer=settings.SUBMISSION_DIR + 'train' + '/tasks_' + wtype +'.csv', 
                            index_col=['seriesuid'])
df_results.index = df_results.index.astype('str')

print('results:', df_results.shape, 'distinct lung:', len(set(df_results.index)))
# Out:
# results: (165965, 7) distinct lung: 1000

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred):
    SMOOTH = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + SMOOTH) / (K.sum(y_true_f) + K.sum(y_pred_f) + SMOOTH)

def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

label = '32'
output_dir = './output/unet3d/1564409333/' # labels in center coord
model = load_model(output_dir + "model-best.hd5", 
                   custom_objects={'dice_coef_loss': dice_coef_loss, 'dice_coef': dice_coef})

# %%
list_results = []
print(wtype, 'window')
for uid in set(df_tasks.index):
    tasks = df_tasks.loc[[uid]] # DataFrame
    meta = df_meta_train.loc[uid] # slice
    
    print('lung:', uid, 'tasks:', len(tasks), 'meta:', meta.slice, meta.height, meta.width)
#     print(meta)
                 
    lung_l, mask_l = helper.load_lung_array(uid, int(meta.width), int(meta.height), int(meta.slice), 
                                            mode='train', wtype=wtype)

    lung = (lung_l*(mask_l>0)).astype('float') / 255

    count = 0
    for idx, item in tasks.iterrows():
        if count % (batch_size*100) == 0:
            X_item = []
            X_test = []

        # patch without mask
        cube = helper.get_cube_from_lung_array(lung, item.vcoordX, item.vcoordY, item.vcoordZ, 
                                               block_size=settings.CUBE_SIZE)

        if np.sum(cube) > 0:
            X_item.append(item)
            X_test.append(cube)
#         else:
#             print('nothing in coord:', '\n', item)

        if (count % (batch_size*100) == (batch_size*100 - 1) or count == len(tasks) - 1) and len(X_test) > 0:
            assert len(X_item) == len(X_test) or count == len(tasks) - 1

            # Make predictions
            X_test = np.expand_dims(np.asarray(X_test), axis=-1)
            print(X_test.shape)
            predictions_test = model.predict(X_test, batch_size=batch_size, verbose=1)

            for i in range(len(X_item)):
                itm = X_item[i]
                pred = predictions_test[i] > threshold_probability
                pred_cube = predictions_test[i,:,:,:,0]
                pred_mask = pred[:,:,:,0]
         
                if np.sum(pred) > 10:
                    vcoords, diameters, bboxes = helper.get_regions_detail(pred_mask, itm)
                    if len(bboxes) > 0:
                        # np.save(settings.SUBMISSION_DIR + 'train' + f'/predicted_cube_{i}.npy', predictions_test[i])
                        for i, b in enumerate(bboxes):
                            result = {}
                            result['seriesuid'] = uid
                            result['vcoordX'] = vcoords[i][2]
                            result['vcoordY'] = vcoords[i][1]
                            result['vcoordZ'] = vcoords[i][0]
                            result['diametersX'] = diameters[i][2]
                            result['diametersY'] = diameters[i][1]
                            result['diametersZ'] = diameters[i][0]
                            
                            region = pred_cube[b[0]:b[3],b[1]:b[4],b[2]:b[5]]
                            result['probability'] = region[region>threshold_probability].mean()
                            if plot:
                                plot_cube((pred_mask*255).astype(np.uint8))

                            list_results.append(result)
                        
        count += 1
   
    # save the csv by per lung
    df_results = pd.DataFrame(list_results, columns=['seriesuid','vcoordX','vcoordY','vcoordZ','diametersX','diametersY','diametersZ','probability'])
    df_results = df_results.set_index('seriesuid')
    df_results.index = df_results.index.astype('str')

    print('total:', df_results.shape, 'lung:', len(set(df_results.index)))

    df_results.to_csv(settings.SUBMISSION_DIR + 'train' + '/tasks_' + wtype + '_' + label + '.csv', encoding='utf-8')

    print('-'*100)
# Out:
# medi window
# lung: 655457 tasks: 567 meta: 230.0 306.0 306.0
# (567, 64, 64, 64, 1)
# 567/567 [==============================] - 13s 23ms/sample
# total: (99, 7) lung: 1
# ----------------------------------------------------------------------------------------------------
# lung: 672912 tasks: 1296 meta: 300.0 401.0 401.0
# (1199, 64, 64, 64, 1)
# 1199/1199 [==============================] - 24s 20ms/sample
# total: (233, 7) lung: 2
# ----------------------------------------------------------------------------------------------------
# lung: 400058 tasks: 729 meta: 320.0 291.0 291.0
# (692, 64, 64, 64, 1)
# 692/692 [==============================] - 13s 19ms/sample
# total: (393, 7) lung: 3
# ----------------------------------------------------------------------------------------------------
# lung: 671752 tasks: 729 meta: 320.0 306.0 306.0
# (719, 64, 64, 64, 1)
# 719/719 [==============================] - 14s 20ms/sample
# total: (507, 7) lung: 4
# ----------------------------------------------------------------------------------------------------
# lung: 656238 tasks: 1089 meta: 294.0 383.0 383.0
# (987, 64, 64, 64, 1)
# 987/987 [==============================] - 19s 19ms/sample
# total: (623, 7) lung: 5
# ----------------------------------------------------------------------------------------------------
# lung: 689860 tasks: 648 meta: 280.0 319.0 319.0
# (626, 64, 64, 64, 1)
# 626/626 [==============================] - 12s 20ms/sample
# total: (723, 7) lung: 6
# ----------------------------------------------------------------------------------------------------
# lung: 656778 tasks: 900 meta: 290.0 333.0 333.0
# (726, 64, 64, 64, 1)
# 726/726 [==============================] - 14s 19ms/sample
# total: (807, 7) lung: 7
# ----------------------------------------------------------------------------------------------------
# lung: 656794 tasks: 1089 meta: 315.0 370.0 370.0
# (975, 64, 64, 64, 1)
# 975/975 [==============================] - 19s 19ms/sample
# total: (929, 7) lung: 8
# ----------------------------------------------------------------------------------------------------
# lung: 639534 tasks: 900 meta: 315.0 350.0 350.0
# (821, 64, 64, 64, 1)
# 821/821 [==============================] - 16s 20ms/sample
# total: (1033, 7) lung: 9
# ----------------------------------------------------------------------------------------------------
# lung: 673869 tasks: 1152 meta: 280.0 391.0 391.0
# (1044, 64, 64, 64, 1)
# 1044/1044 [==============================] - 21s 20ms/sample
# total: (1178, 7) lung: 10
# ----------------------------------------------------------------------------------------------------
# lung: 653671 tasks: 700 meta: 252.0 350.0 350.0
# (668, 64, 64, 64, 1)
# 668/668 [==============================] - 13s 20ms/sample
# total: (1270, 7) lung: 11
# ----------------------------------------------------------------------------------------------------
# lung: 682056 tasks: 900 meta: 310.0 350.0 350.0
# (899, 64, 64, 64, 1)
# 899/899 [==============================] - 18s 20ms/sample
# total: (1391, 7) lung: 12
# ----------------------------------------------------------------------------------------------------
# lung: 656074 tasks: 729 meta: 315.0 318.0 318.0
# (695, 64, 64, 64, 1)
# 695/695 [==============================] - 13s 19ms/sample
# total: (1515, 7) lung: 13
# ----------------------------------------------------------------------------------------------------
# lung: 664003 tasks: 700 meta: 256.0 330.0 330.0
# (700, 64, 64, 64, 1)
# 700/700 [==============================] - 14s 20ms/sample
# total: (1619, 7) lung: 14
# ----------------------------------------------------------------------------------------------------
# lung: 529278 tasks: 1331 meta: 355.0 379.0 379.0
# (1167, 64, 64, 64, 1)
# 1167/1167 [==============================] - 23s 19ms/sample
# total: (1774, 7) lung: 15
# ----------------------------------------------------------------------------------------------------
# lung: 672344 tasks: 900 meta: 300.0 350.0 350.0
# (880, 64, 64, 64, 1)
# 880/880 [==============================] - 17s 19ms/sample
# total: (1900, 7) lung: 16
# ----------------------------------------------------------------------------------------------------
# lung: 647210 tasks: 800 meta: 285.0 350.0 350.0
# (754, 64, 64, 64, 1)
# 754/754 [==============================] - 14s 19ms/sample
# total: (2024, 7) lung: 17
# ----------------------------------------------------------------------------------------------------
# lung: 689340 tasks: 968 meta: 285.0 378.0 378.0
# (873, 64, 64, 64, 1)
# 873/873 [==============================] - 17s 19ms/sample
# total: (2135, 7) lung: 18
# ----------------------------------------------------------------------------------------------------
# lung: 655431 tasks: 1296 meta: 312.0 407.0 407.0
# (995, 64, 64, 64, 1)
# 995/995 [==============================] - 19s 19ms/sample
# total: (2231, 7) lung: 19
# ----------------------------------------------------------------------------------------------------
# lung: 664658 tasks: 500 meta: 170.0 350.0 350.0
# (481, 64, 64, 64, 1)
# 481/481 [==============================] - 9s 19ms/sample
# total: (2328, 7) lung: 20
# ----------------------------------------------------------------------------------------------------
# lung: 655992 tasks: 1100 meta: 365.0 350.0 350.0
# (1011, 64, 64, 64, 1)
# 1011/1011 [==============================] - 19s 19ms/sample
# total: (2432, 7) lung: 21
# ----------------------------------------------------------------------------------------------------
# lung: 681379 tasks: 1008 meta: 256.0 385.0 385.0
# (956, 64, 64, 64, 1)
# 956/956 [==============================] - 19s 20ms/sample
# total: (2534, 7) lung: 22
# ----------------------------------------------------------------------------------------------------
# lung: 679994 tasks: 700 meta: 255.0 350.0 350.0
# (660, 64, 64, 64, 1)
# 660/660 [==============================] - 13s 20ms/sample
# total: (2635, 7) lung: 23
# ----------------------------------------------------------------------------------------------------
# lung: 631673 tasks: 567 meta: 250.0 314.0 314.0
# (565, 64, 64, 64, 1)
# 565/565 [==============================] - 11s 19ms/sample
# total: (2728, 7) lung: 24
# ----------------------------------------------------------------------------------------------------
# lung: 671750 tasks: 648 meta: 270.0 320.0 320.0
# (628, 64, 64, 64, 1)
# 628/628 [==============================] - 13s 20ms/sample
# total: (2794, 7) lung: 25
# ----------------------------------------------------------------------------------------------------
# lung: 688185 tasks: 900 meta: 300.0 322.0 322.0
# (808, 64, 64, 64, 1)
# 808/808 [==============================] - 16s 20ms/sample
# total: (2904, 7) lung: 26
# ----------------------------------------------------------------------------------------------------
# lung: 684424 tasks: 968 meta: 275.0 359.0 359.0
# (846, 64, 64, 64, 1)
# 846/846 [==============================] - 17s 20ms/sample
# total: (2984, 7) lung: 27
# ----------------------------------------------------------------------------------------------------
# lung: 688225 tasks: 847 meta: 245.0 357.0 357.0
# (788, 64, 64, 64, 1)
# 788/788 [==============================] - 15s 20ms/sample
# total: (3095, 7) lung: 28
# ----------------------------------------------------------------------------------------------------
# lung: 656881 tasks: 1000 meta: 345.0 350.0 350.0
# (915, 64, 64, 64, 1)
# 915/915 [==============================] - 18s 20ms/sample
# total: (3238, 7) lung: 29
# ----------------------------------------------------------------------------------------------------
# lung: 690660 tasks: 567 meta: 231.0 319.0 319.0
# (498, 64, 64, 64, 1)
# 498/498 [==============================] - 10s 19ms/sample
# total: (3326, 7) lung: 30
# ----------------------------------------------------------------------------------------------------
# lung: 695349 tasks: 648 meta: 285.0 317.0 317.0
# (606, 64, 64, 64, 1)
# 606/606 [==============================] - 12s 19ms/sample
# total: (3415, 7) lung: 31
# ----------------------------------------------------------------------------------------------------
# lung: 647735 tasks: 900 meta: 300.0 350.0 350.0
# (879, 64, 64, 64, 1)
# 879/879 [==============================] - 17s 19ms/sample
# total: (3527, 7) lung: 32
# ----------------------------------------------------------------------------------------------------
# lung: 689252 tasks: 1584 meta: 365.0 392.0 392.0
# (1404, 64, 64, 64, 1)
# 1404/1404 [==============================] - 27s 20ms/sample
# total: (3714, 7) lung: 33
# ----------------------------------------------------------------------------------------------------
# lung: 656403 tasks: 1440 meta: 324.0 394.0 394.0
# (1188, 64, 64, 64, 1)
# 1188/1188 [==============================] - 23s 20ms/sample
# total: (3851, 7) lung: 34
# ----------------------------------------------------------------------------------------------------
# lung: 655574 tasks: 968 meta: 280.0 381.0 381.0
# (906, 64, 64, 64, 1)
# 906/906 [==============================] - 17s 19ms/sample
# total: (3990, 7) lung: 35
# ----------------------------------------------------------------------------------------------------
# lung: 520069 tasks: 1690 meta: 340.0 427.0 427.0
# (1433, 64, 64, 64, 1)
# 1433/1433 [==============================] - 28s 20ms/sample
# total: (4116, 7) lung: 36
# ----------------------------------------------------------------------------------------------------
# lung: 691784 tasks: 900 meta: 300.0 350.0 350.0
# (871, 64, 64, 64, 1)
# 871/871 [==============================] - 17s 19ms/sample
# total: (4223, 7) lung: 37
# ----------------------------------------------------------------------------------------------------
# lung: 689288 tasks: 900 meta: 300.0 350.0 350.0
# (862, 64, 64, 64, 1)
# 862/862 [==============================] - 17s 19ms/sample
# total: (4359, 7) lung: 38
# ----------------------------------------------------------------------------------------------------
# lung: 696427 tasks: 968 meta: 280.0 357.0 357.0
# (951, 64, 64, 64, 1)
# 951/951 [==============================] - 18s 19ms/sample
# total: (4497, 7) lung: 39
# ----------------------------------------------------------------------------------------------------
# lung: 672672 tasks: 640 meta: 340.0 282.0 282.0
# (614, 64, 64, 64, 1)
# 614/614 [==============================] - 12s 20ms/sample
# total: (4605, 7) lung: 40
# ----------------------------------------------------------------------------------------------------
# lung: 655376 tasks: 1690 meta: 330.0 436.0 436.0
# (1284, 64, 64, 64, 1)
# 1284/1284 [==============================] - 25s 19ms/sample
# total: (4758, 7) lung: 41
# ----------------------------------------------------------------------------------------------------
# lung: 388509 tasks: 1152 meta: 285.0 406.0 406.0
# (1032, 64, 64, 64, 1)
# 1032/1032 [==============================] - 20s 20ms/sample
# total: (4915, 7) lung: 42
# ----------------------------------------------------------------------------------------------------
# lung: 648146 tasks: 1000 meta: 340.0 350.0 350.0
# (999, 64, 64, 64, 1)
# 999/999 [==============================] - 20s 20ms/sample
# total: (5053, 7) lung: 43
# ----------------------------------------------------------------------------------------------------
# lung: 648428 tasks: 512 meta: 260.0 288.0 288.0
# (512, 64, 64, 64, 1)
# 512/512 [==============================] - 11s 21ms/sample
# total: (5167, 7) lung: 44
# ----------------------------------------------------------------------------------------------------
# lung: 657280 tasks: 800 meta: 270.0 350.0 350.0
# (702, 64, 64, 64, 1)
# 702/702 [==============================] - 14s 20ms/sample
# total: (5290, 7) lung: 45
# ----------------------------------------------------------------------------------------------------
# lung: 676182 tasks: 648 meta: 260.0 312.0 312.0
# (556, 64, 64, 64, 1)
# 556/556 [==============================] - 11s 19ms/sample
# total: (5399, 7) lung: 46
# ----------------------------------------------------------------------------------------------------
# lung: 689390 tasks: 800 meta: 280.0 350.0 350.0
# (792, 64, 64, 64, 1)
# 792/792 [==============================] - 16s 20ms/sample
# total: (5531, 7) lung: 47
# ----------------------------------------------------------------------------------------------------
# lung: 655698 tasks: 1000 meta: 330.0 350.0 350.0
# (917, 64, 64, 64, 1)
# 917/917 [==============================] - 18s 20ms/sample
# total: (5643, 7) lung: 48
# ----------------------------------------------------------------------------------------------------
# lung: 655426 tasks: 900 meta: 310.0 339.0 339.0
# (832, 64, 64, 64, 1)
# 832/832 [==============================] - 16s 19ms/sample
# total: (5768, 7) lung: 49
# ----------------------------------------------------------------------------------------------------
# lung: 664574 tasks: 1000 meta: 350.0 350.0 350.0
# (901, 64, 64, 64, 1)
# 901/901 [==============================] - 17s 19ms/sample
# total: (5897, 7) lung: 50
# ----------------------------------------------------------------------------------------------------
# lung: 382339 tasks: 847 meta: 238.0 370.0 370.0
# (705, 64, 64, 64, 1)
# 705/705 [==============================] - 14s 20ms/sample
# total: (6014, 7) lung: 51
# ----------------------------------------------------------------------------------------------------
# lung: 682359 tasks: 729 meta: 305.0 291.0 291.0
# (701, 64, 64, 64, 1)
# 701/701 [==============================] - 14s 20ms/sample
# total: (6118, 7) lung: 52
# ----------------------------------------------------------------------------------------------------
# lung: 653891 tasks: 900 meta: 305.0 350.0 350.0
# (898, 64, 64, 64, 1)
# 898/898 [==============================] - 17s 19ms/sample
# total: (6315, 7) lung: 53
# ----------------------------------------------------------------------------------------------------
# lung: 397750 tasks: 1584 meta: 360.0 390.0 390.0
# (1149, 64, 64, 64, 1)
# 1149/1149 [==============================] - 22s 19ms/sample
# total: (6467, 7) lung: 54
# ----------------------------------------------------------------------------------------------------
# lung: 503406 tasks: 1296 meta: 296.0 396.0 396.0
# (1056, 64, 64, 64, 1)
# 1056/1056 [==============================] - 21s 20ms/sample
# total: (6616, 7) lung: 55
# ----------------------------------------------------------------------------------------------------
# lung: 663672 tasks: 700 meta: 250.0 350.0 350.0
# (665, 64, 64, 64, 1)
# 665/665 [==============================] - 14s 20ms/sample
# total: (6746, 7) lung: 56
# ----------------------------------------------------------------------------------------------------
# lung: 543981 tasks: 2700 meta: 400.0 500.0 500.0
# (1729, 64, 64, 64, 1)
# 1729/1729 [==============================] - 33s 19ms/sample
# total: (6969, 7) lung: 57
# ----------------------------------------------------------------------------------------------------
# lung: 637993 tasks: 900 meta: 310.0 350.0 350.0
# (864, 64, 64, 64, 1)
# 864/864 [==============================] - 17s 20ms/sample
# total: (7093, 7) lung: 58
# ----------------------------------------------------------------------------------------------------
# lung: 679809 tasks: 900 meta: 300.0 350.0 350.0
# (886, 64, 64, 64, 1)
# 886/886 [==============================] - 18s 20ms/sample
# total: (7212, 7) lung: 59
# ----------------------------------------------------------------------------------------------------
# lung: 672499 tasks: 810 meta: 330.0 318.0 318.0
# (785, 64, 64, 64, 1)
# 785/785 [==============================] - 16s 20ms/sample
# total: (7331, 7) lung: 60
# ----------------------------------------------------------------------------------------------------
# lung: 655394 tasks: 1296 meta: 301.0 410.0 410.0
# (1132, 64, 64, 64, 1)
# 1132/1132 [==============================] - 22s 19ms/sample
# total: (7461, 7) lung: 61
# ----------------------------------------------------------------------------------------------------
# lung: 697125 tasks: 729 meta: 304.0 317.0 317.0
# (687, 64, 64, 64, 1)
# 687/687 [==============================] - 14s 20ms/sample
# total: (7551, 7) lung: 62
# ----------------------------------------------------------------------------------------------------
# lung: 682499 tasks: 1089 meta: 310.0 354.0 354.0
# (1028, 64, 64, 64, 1)
# 1028/1028 [==============================] - 21s 20ms/sample
# total: (7665, 7) lung: 63
# ----------------------------------------------------------------------------------------------------
# lung: 674849 tasks: 968 meta: 275.0 371.0 371.0
# (869, 64, 64, 64, 1)
# 869/869 [==============================] - 18s 20ms/sample
# total: (7751, 7) lung: 64
# ----------------------------------------------------------------------------------------------------
# lung: 320188 tasks: 968 meta: 280.0 370.0 370.0
# (827, 64, 64, 64, 1)
# 827/827 [==============================] - 16s 20ms/sample
# total: (7881, 7) lung: 65
# ----------------------------------------------------------------------------------------------------
# lung: 645337 tasks: 900 meta: 320.0 350.0 350.0
# (812, 64, 64, 64, 1)
# 812/812 [==============================] - 16s 20ms/sample
# total: (8004, 7) lung: 66
# ----------------------------------------------------------------------------------------------------
# lung: 502378 tasks: 512 meta: 260.0 280.0 280.0
# (481, 64, 64, 64, 1)
# 481/481 [==============================] - 10s 20ms/sample
# total: (8096, 7) lung: 67
# ----------------------------------------------------------------------------------------------------
# lung: 402074 tasks: 726 meta: 210.0 370.0 370.0
# (625, 64, 64, 64, 1)
# 625/625 [==============================] - 13s 20ms/sample
# total: (8191, 7) lung: 68
# ----------------------------------------------------------------------------------------------------
# lung: 696418 tasks: 800 meta: 285.0 350.0 350.0
# (730, 64, 64, 64, 1)
# 730/730 [==============================] - 14s 20ms/sample
# total: (8299, 7) lung: 69
# ----------------------------------------------------------------------------------------------------
# lung: 657065 tasks: 1000 meta: 328.0 330.0 330.0
# (924, 64, 64, 64, 1)
# 924/924 [==============================] - 18s 20ms/sample
# total: (8464, 7) lung: 70
# ----------------------------------------------------------------------------------------------------
# lung: 687474 tasks: 900 meta: 310.0 350.0 350.0
# (859, 64, 64, 64, 1)
# 859/859 [==============================] - 17s 20ms/sample
# total: (8570, 7) lung: 71
# ----------------------------------------------------------------------------------------------------
# lung: 628766 tasks: 900 meta: 300.0 350.0 350.0
# (876, 64, 64, 64, 1)
# 876/876 [==============================] - 17s 20ms/sample
# total: (8704, 7) lung: 72
# ----------------------------------------------------------------------------------------------------
# lung: 698734 tasks: 600 meta: 200.0 326.0 326.0
# (562, 64, 64, 64, 1)
# 562/562 [==============================] - 11s 19ms/sample
# total: (8799, 7) lung: 73
# ----------------------------------------------------------------------------------------------------
# lung: 688374 tasks: 648 meta: 270.0 309.0 309.0
# (605, 64, 64, 64, 1)
# 605/605 [==============================] - 12s 20ms/sample
# total: (8872, 7) lung: 74
# ----------------------------------------------------------------------------------------------------
# lung: 693057 tasks: 1296 meta: 300.0 397.0 397.0
# (1197, 64, 64, 64, 1)
# 1197/1197 [==============================] - 23s 19ms/sample
# total: (9048, 7) lung: 75
# ----------------------------------------------------------------------------------------------------
# lung: 656835 tasks: 1210 meta: 333.0 356.0 356.0
# (997, 64, 64, 64, 1)
# 997/997 [==============================] - 20s 20ms/sample
# total: (9192, 7) lung: 76
# ----------------------------------------------------------------------------------------------------
# lung: 657237 tasks: 1100 meta: 365.0 341.0 341.0
# (962, 64, 64, 64, 1)
# 962/962 [==============================] - 19s 20ms/sample
# total: (9342, 7) lung: 77
# ----------------------------------------------------------------------------------------------------
# lung: 688892 tasks: 1000 meta: 325.0 340.0 340.0
# (955, 64, 64, 64, 1)
# 955/955 [==============================] - 18s 19ms/sample
# total: (9459, 7) lung: 78
# ----------------------------------------------------------------------------------------------------
# lung: 655633 tasks: 810 meta: 325.0 302.0 302.0
# (778, 64, 64, 64, 1)
# 778/778 [==============================] - 15s 19ms/sample
# total: (9600, 7) lung: 79
# ----------------------------------------------------------------------------------------------------
# lung: 689544 tasks: 1100 meta: 365.0 350.0 350.0
# (1008, 64, 64, 64, 1)
# 1008/1008 [==============================] - 19s 19ms/sample
# total: (9757, 7) lung: 80
# ----------------------------------------------------------------------------------------------------
# lung: 688928 tasks: 1089 meta: 295.0 364.0 364.0
# (994, 64, 64, 64, 1)
# 994/994 [==============================] - 20s 20ms/sample
# total: (9905, 7) lung: 81
# ----------------------------------------------------------------------------------------------------
# lung: 671831 tasks: 900 meta: 295.0 352.0 352.0
# (811, 64, 64, 64, 1)
# 811/811 [==============================] - 16s 19ms/sample
# total: (10014, 7) lung: 82
# ----------------------------------------------------------------------------------------------------
# lung: 656465 tasks: 1352 meta: 270.0 441.0 441.0
# (1175, 64, 64, 64, 1)
# 1175/1175 [==============================] - 23s 19ms/sample
# total: (10133, 7) lung: 83
# ----------------------------------------------------------------------------------------------------
# lung: 648061 tasks: 1296 meta: 310.0 390.0 390.0
# (1228, 64, 64, 64, 1)
# 1228/1228 [==============================] - 25s 20ms/sample
# total: (10310, 7) lung: 84
# ----------------------------------------------------------------------------------------------------
# lung: 657795 tasks: 648 meta: 285.0 313.0 313.0
# (584, 64, 64, 64, 1)
# 584/584 [==============================] - 12s 20ms/sample
# total: (10429, 7) lung: 85
# ----------------------------------------------------------------------------------------------------
# lung: 689124 tasks: 1000 meta: 350.0 341.0 341.0
# (969, 64, 64, 64, 1)
# 969/969 [==============================] - 19s 19ms/sample
# total: (10570, 7) lung: 86
# ----------------------------------------------------------------------------------------------------
# lung: 682280 tasks: 1089 meta: 305.0 384.0 384.0
# (1035, 64, 64, 64, 1)
# 1035/1035 [==============================] - 20s 20ms/sample
# total: (10722, 7) lung: 87
# ----------------------------------------------------------------------------------------------------
# lung: 414510 tasks: 1089 meta: 290.0 368.0 368.0
# (955, 64, 64, 64, 1)
# 955/955 [==============================] - 19s 20ms/sample
# total: (10878, 7) lung: 88
# ----------------------------------------------------------------------------------------------------
# lung: 401070 tasks: 486 meta: 215.0 296.0 296.0
# (454, 64, 64, 64, 1)
# 454/454 [==============================] - 9s 19ms/sample
# total: (10960, 7) lung: 89
# ----------------------------------------------------------------------------------------------------
# lung: 632344 tasks: 700 meta: 230.0 350.0 350.0
# (683, 64, 64, 64, 1)
# 683/683 [==============================] - 13s 20ms/sample
# total: (11072, 7) lung: 90
# ----------------------------------------------------------------------------------------------------
# lung: 657853 tasks: 1296 meta: 300.0 392.0 392.0
# 1089/1089 [==============================] - 21s 19ms/sample
# total: (11184, 7) lung: 91
# ----------------------------------------------------------------------------------------------------
# lung: 697073 tasks: 900 meta: 300.0 350.0 350.0
# (856, 64, 64, 64, 1)
# 856/856 [==============================] - 16s 19ms/sample
# total: (11309, 7) lung: 92
# ----------------------------------------------------------------------------------------------------
# lung: 656330 tasks: 1000 meta: 325.0 350.0 350.0
# (874, 64, 64, 64, 1)
# 874/874 [==============================] - 17s 20ms/sample
# total: (11449, 7) lung: 93
# ----------------------------------------------------------------------------------------------------
# lung: 655432 tasks: 847 meta: 252.0 378.0 378.0
# (810, 64, 64, 64, 1)
# 810/810 [==============================] - 16s 20ms/sample
# total: (11555, 7) lung: 94
# ----------------------------------------------------------------------------------------------------
# lung: 390571 tasks: 648 meta: 280.0 303.0 303.0
# (633, 64, 64, 64, 1)
# 633/633 [==============================] - 12s 20ms/sample
# total: (11635, 7) lung: 95
# ----------------------------------------------------------------------------------------------------
# lung: 688190 tasks: 800 meta: 270.0 350.0 350.0
# (749, 64, 64, 64, 1)
# 749/749 [==============================] - 15s 19ms/sample
# total: (11738, 7) lung: 96
# ----------------------------------------------------------------------------------------------------
# lung: 689419 tasks: 1000 meta: 321.0 350.0 350.0
# (967, 64, 64, 64, 1)
# 967/967 [==============================] - 19s 20ms/sample
# total: (11906, 7) lung: 97
# ----------------------------------------------------------------------------------------------------
# lung: 639006 tasks: 576 meta: 300.0 280.0 280.0
# (571, 64, 64, 64, 1)
# 571/571 [==============================] - 11s 20ms/sample
# total: (12017, 7) lung: 98
# ----------------------------------------------------------------------------------------------------
# lung: 630889 tasks: 800 meta: 270.0 346.0 346.0
# (792, 64, 64, 64, 1)
# 792/792 [==============================] - 15s 20ms/sample
# total: (12122, 7) lung: 99
# ----------------------------------------------------------------------------------------------------
# lung: 663638 tasks: 900 meta: 315.0 350.0 350.0
# (876, 64, 64, 64, 1)
# 876/876 [==============================] - 17s 20ms/sample
# total: (12281, 7) lung: 100
# ----------------------------------------------------------------------------------------------------

# %%
df_results = pd.read_csv(filepath_or_buffer=settings.SUBMISSION_DIR + 'train' + '/tasks_' + wtype + '_' + label + '.csv', 
                            index_col=['seriesuid'])
df_results.index = df_results.index.astype('str')

print('results:', df_results.shape, 'distinct lung:', len(set(df_results.index)))
# Out:
# results: (12281, 7) distinct lung: 100

# %%
filepath_31 = settings.SUBMISSION_DIR + 'train' + '/tasks_' + wtype +'_31.csv'
filepath_32 = settings.SUBMISSION_DIR + 'train' + '/tasks_' + wtype +'_32.csv'
if os.path.exists(filepath_31) and os.path.exists(filepath_32):
    df_medi_31 = pd.read_csv(filepath_or_buffer=filepath_31, index_col=['seriesuid'])
    df_medi_31.index = df_medi_31.index.astype('str')
    print('medi window 31:', df_medi_31.shape)
    
    df_medi_32 = pd.read_csv(filepath_or_buffer=filepath_32, index_col=['seriesuid'])
    df_medi_32.index = df_medi_32.index.astype('str')
    print('medi window 32:', df_medi_32.shape)
    
    df_medi = pd.concat([df_medi_31, df_medi_32])
    print('medi windows merged:', df_medi.shape)
    df_medi.to_csv(settings.SUBMISSION_DIR + 'train' + '/tasks_' + wtype +'.csv', encoding='utf-8')
# Out:
# medi window 31: (13277, 7)
# medi window 32: (12281, 7)
# medi windows merged: (25558, 7)
